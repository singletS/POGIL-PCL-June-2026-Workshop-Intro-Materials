# %% [markdown]
# This notebook is based on a notebook that was originally authored by Jonathan Gutow, Melissa Reeves, and Tricia Shepherd, which has been extended with additional examples from the POGIL-PCL Intro to Jupyter Notebooks Workshop team. (Please provide attribution if you use this notebook in another setting, including if you use an altered version.)
#
# This notebook was originally used in a small-group setting; prompts to "discuss with your team" may need to be answered as an individual if not working with a team.

# %% [markdown]
# # <font color=cornflowerblue>Introduction</font>
#
# A jupyter notebook is composed of two different components: white cells that contain **text** (like this one), and shaded cells that contain **code** (like the one below). As you work through this notebook, you will need to execute each *code cell* by first clicking on the shaded area and then the play button that appears at the top left corner before moving on to the next cell. When instructed you can add a *code cell* or a *text cell* by selecting the appropriate option (+ Code or + Text) from the menu bar just above this cell.  Text cell text can be formatted using Markdown: https://www.markdownguide.org/cheat-sheet/.  You will see examples of markdown in text blocks throughout this notebook.
#
#
# 0. Other than the white background/shaded background identify one other feature that differs between text cells and code cells.  Type your answer in this box.
#
# 1. Execute the code cell below to run import statements that make available functions used in this notebook.  Note that this block should be executed before any other code blocks in the notebook.  List three things that you notice as you review the first code block.

# %%
# A jupyter notebook will usually contain library import statements in its first code block
# to provide access to functions used throughout the notebook.

import numpy as np              #library expands python support for large and multidimensional arrays.
import matplotlib.pyplot as plt #plotting and graphing library

# %% [markdown]
# ## <font color=cornflowerblue>Model 1: Calculator</font>
# ### <font color=green>A jupyter notebook can be used as a calculator.</font>

# %% [markdown]
# 2. In your teams, complete the following statements. (Double click to type in this *text cell*.)
#
# 2+3 =
#
# 3*4+2 =
#
# 3**4+2 =
#
# 3(4+2) =
#
# 2*(9+2) =
#
# 3/2*5 =
#
# 3/(2*5) =

# %% [markdown]
# 3. Your answers above could be considered predictions of what can be calculated within a jupyter notebook.  Check your predictions in the *code cell* below by entering and executing each expression above <u>one at a time</u>. You may either edit the code cell below or create a new code cell for each calculation. The first is provided as an example.
#
#
# *   In the *text cell* above, provide a reason for any output that differs from your prediction.
# *   How does python notation compare to notation used in a spreadsheet program like Excel? List similarities and differences.

# %%
# Calculate arithmetic

2+3

# %% [markdown]
# 4.  On a piece of paper, write the equation needed to determine the pressure in atm exerted by 1.15 moles of He in a cube 2.0 cm on a side at 315 K. Use your calculator to determine the answer. Then add a code cell below to perform the same calculation.
#
# > With your team, compare each member's numerical answers.  If they differ, compare the code blocks to see how and why they differ. Edit your code cell as needed so that all team members are confident they have the correct answer.

# %% [markdown]
# ## <font color=cornflowerblue>Model 2: Variables</font>
# ### <font color=green>Python coding in a jupyter notebook can be used to *assign a value to a variable*.

# %%
# Assign a variable a value
  # A variable can be any combination of alphanumeric symbols that begins with a letter.

Temp = 315   # Assign a variable for temperature (K).
  # The variable is found to the left of the "=" and the assigned value is found to the right.
  # Variable names can be any single letter or a group of letters and numbers that describe the variable.
  # You should avoid using lowercase l and uppercase O for Single letter variables since those are easily confused with numbers 1 and 0.

# Assign a variable using operations involving assigned variables.

SquareTemp = Temp**2 # Notice that the "raise to the power" operator in python is "**", not "^".

CubedTemp = Temp*SquareTemp

# Display variables

Temp, SquareTemp, CubedTemp

# %% [markdown]
# 5. Make a note of the output and then edit the *code cell* above assigning a different value to Temp, *e.g.,* 200. Is there a difference in the output when you execute the code?

# %% [markdown]
# 6. Add a *code cell* below and assign each number to a variable in order to calculate the pressure of 1.15 moles of helium gas in a cube 2.0 cm on a side at 315 K. Display the value of the pressure variable.  Check your result to confirm that it agrees with the result above that used numbers instead of variables.

# %% [markdown]
# 7. Discuss with your team when and why you might prefer to use variables rather than use numbers like a calculator, then add a *text cell* below and describe one advantage of assigning a number to a variable before using it in a calculation rather than just entering all numbers like a calculator.

# %% [markdown]
# ## <font color=cornflowerblue>Model 3: Arrays</font>
# ### <font color=green>Sets of data can be assigned to a variable. These sets are called arrays.

# %% [markdown]
# 8. Review the following *code cell* and predict what the output will be.  Discuss your prediction with your team members, then run the *code cell*.  Was your prediction accurate?  If not, create a *text cell* and describe what was different than you predicted.

# %%
# Assign an array

TempAr = np.array([145,160,200,205])    # Assign an array of temperatures for a sample of argon gas.
  # notice that we are using an array function from the numpy (np) library to create the array.
  # You will see "np." functions from numpy again later in this worksheet.

distance = np.arange(0,10)    # Create an array filled with a series of 10 integers starting at 0.

# Assign an array using operations involving arrays

SquareTempAr = TempAr**2

radii = distance*0.1

# Display arrays

TempAr, distance, SquareTempAr, radii

# %% [markdown]
# 9. Add a *text cell* below and describe both the difference and reason for the difference between SquareTemp (Model 2) and SquareTempAr (Model 3).

# %% [markdown]
# 10. Add a *code cell* below and calculate the pressure at 5 different container volumes for a 0.25 mol Ar sample at 315 K.

# %% [markdown]
# 11. Discuss with your team when it would be useful to use arrays in a calculation, then add a *text cell* below and describe one advantage of using an array in a calculation.

# %% [markdown]
# ## <font color=cornflowerblue>Model 4: Graphing</font>
# ### <font color=green>A jupyter notebook can be used to visually present the relationship betweeen two quantities.
#
# Running the code cell below creates a plot showing the relationship between time and the mass of dry chick peas that are soaking up water (This data was generated when carrying out the POGIL-PCL experiment: "Can we make stew with these beans?").

# %%
# Assign arrays corresponding to x and different y's

Time = np.array([0,2.5,5,7.5,10,20,30,60])

Water = np.array([10.293,11.044,11.746,12.093,12.505,13.133,13.689,14.672])

NaCl3M = np.array([9.611,10.174,10.387,10.672,10.903,11.433,11.745,13.415])

# Plot data
# Marker options here: https://matplotlib.org/stable/api/markers_api.html
# Color options here: https://matplotlib.org/stable/gallery/color/named_colors.html
# Examples of plot types here: https://matplotlib.org/stable/gallery/index.html

plt.plot(Time,Water,marker="o",linestyle='None')

plt.plot(Time,NaCl3M,marker='x',color='r',linestyle='None')

plt.xlabel("Time (min)")

plt.ylabel("Mass (g)");

plt.legend(['Water',  '3M NaCl'], loc='lower right')

# %% [markdown]
# 12. Copy the previous *code cell* and add a comment to each line describing what that line of code does, including any function arguments.  Review your comments with the other members of your team and reconcile any disagreement.

# %% [markdown]
# 13. Add the following data for 2.0 M NaCl to the *code cell* that you just created: [10.299,10.780,11.125,11.454,11.682,12.033,12.453,12.843]. Use a different marker and color for the new data set and run your new code block.  Compare your results to those of your team. Review and correct any errors that might appear and re-execute the code.  Repeat until your new plots correctly show all three data sets with different colors and markers for each data set.

# %% [markdown]
# ## <font color=cornflowerblue>Model 5: Functions</font>
# ### <font color=green> A jupyter notebook can execute a number of common mathematical functions
# We have already used the NumPy array function and we will be using more numpy functions in the following sections.  NumPy also provides many common mathematical functions that can be applied to arrays of numbers.  This link contains more information about math functions that are available in numpy:
# https://numpy.org/doc/stable/reference/routines.math.html.

# %%
# Assign a variable a value

C0 = 1.0           # Initial concentration (M)
k = 1.0E-3         # 1st order rate constant (1/s)
time =20           # Time (s)

# Assign a variable using functions and operations of assigned variables

Conc = C0*np.exp(-k*time)

lnConc = np.log(C0)-k*time    # np.log() is the numpy natural log

# Display variables

Conc, lnConc

# %% [markdown]
# 14. Add a *text cell* below and identify the code used to represent the exponential and natural log functions.

# %% [markdown]
# 15. Based on the name pattern of functions in the two examples above,  add a *code cell* below and calculate the sine of pi/4, pi/2, and pi. NOTE: the constant pi is accessed as np.pi.

# %% [markdown]
# 16. Add a code cell below to create a plot of two cycles of a sine wave, 0..4$\pi$.

# %% [markdown]
# 17. Modify the previous plot by adding a second sine function of different frequency, amplitude, and phase factor, then add a plot of the sum of this sine function with the original.  With your team, discuss what physical chemistry concepts could be illustrated using this example?  Summarize your team's discussion in a text box following the plot.

# %% [markdown]
# **Optional Homework:** Practice by choosing some example from your own course that you could use a Jupyter Notebook to do a calculation and draw a plot.
